# %% [markdown]
# # Demo: Universal Inverse Problem
#
# In this notebook, you can (1) load a pre-trained denoiser from the "denoisers" directory; (2) generate sample patches from the image prior embedded in that denoiser; and (3) use the embedded prior to solve ("regularize") any of 5 example linear inverse problems.

# %%
import numpy as np
from skimage.metrics import structural_similarity, peak_signal_noise_ratio
import matplotlib.pylab as plt
import os
import time
import torch
import sys
sys.path.insert(0, 'code')
from Utils_inverse_prob import *
from network import *
from algorithm_inv_prob import *

# %matplotlib inline
# Out:
# usetex mode requires TeX.
# usetex mode requires TeX.

# %% [markdown]
# # load a denoiser
#
# Different denoisers embed different priors. In the context of deep neural networks, the learned prior depends on both the network architecture and the training dataset. Changing the architecture and/or the training set results in generated samples which are qualitatively different.
#
# **Using other denoisers:** You can add any other denoiser to the 'denoisers' directory and use it in our algorithm to sample from its implicit prior. Note that the denoiser has to be
# * optimized to remove additive white Gaussian noise, minimizing mean squared error,
# * universal (i.e. can remove noise of any amplitude),
# * blind (i.e. operates directly on the noisy image, without explicit knowledge of the noise level).

# %% [markdown]
# ### 1. Denoiser architecture

# %%
# Print a list of pre-trained denoiser architectures
print( os.listdir('denoisers'))

# Choose an architecture from the list
architecture = 'BF_CNN'
# architecture = 'DnCNN'
# # architecture ='GSDRUNet'
# architecture = 'TV'
# Out:
# ['BF_CNN', 'DnCNN']

# %% [markdown]
# ### 2. Training dataset

# %%
# Print a list of training datasets associated with the architecture
print(os.listdir(os.path.join('denoisers',architecture)))

# Choose a trainig set:
training_data = 'BSD300_color' 

if 'color' in training_data.split('_'): 
    grayscale = False # number of input and output channels is 3
    C = 3
else: 
    grayscale = True # number of input and output channels is 1
    C = 1
# Out:
# ['algorithm_inv_prob.py', 'BSD300_color', 'BSD400_gray', 'mnist_gray']

# %%
# Now, choose the range of noise used during training from the list below
print(os.listdir(os.path.join('denoisers',architecture,training_data)))

training_noise='noise_range_0to100'
# Out:
# ['noise_range_0to100']

# %%
denoiser = load_denoiser(architecture=architecture, 
                         grayscale=grayscale, 
                         training_data=training_data, 
                         training_noise=training_noise)

denoiser.eval();

# %% [markdown]
# # Image synthesis
#
# Here, we draw samples from the prior. Starting from an arbitrary point in the space of images (more specifically, an image of Gaussian noise with large variance) we use the denoiser to ascend the gradient of the implicit prior. The procedure relies on the following hyperparameters:
#
# * $\sigma_0$: sig_0 is the standard deviation of the noise used to generate the initial image. Default = 1
#
# * $h_0$: h0 is the step size, expressed as a fraction in the range $[0,1]$ of the denoising correction that is taken. Default = 0.01
#
# * $\beta$: beta controls the amount of noise injected in each iteration. $\beta \in (0,1] $, with smaller values indicating more noise ($\beta = 1$ indicating no noise).  Injecting noise allows the alorithm to escape local minima, changing the qualitative properties of the samples
#
# * $\sigma_L$: sig_L is the stopping criterion. When the noise remaining in the synthesized image reaches this level (as determined by the amplitude of the denoiser correction), the algorithm terminates, returning the current image (a sample from $p_{\sigma_L}(y) \approx p(x)$).  Default = 0.01
#
# Additionally, you can adjust the following:
# * patch_size: patch size to be generated
# * freq: frequency with which intermediate samples are saved in interm_Ys (0 = don't save samples)

# %%
# %%script false --no-raise-error
# # choose the size of the sample patch:
# patch_size = (C,40,40) #choose 28x28 for mnist patch size
# x_c = torch.zeros(patch_size)
# if torch.cuda.is_available():
#     x = x.cuda()
#
# synth = synthesis()
# sample, interm_Ys = univ_inv_sol_gsdrunet(denoiser,
#                                  x_c = x_c,
#                                  task = synth,
#                                  sig_0 = 1,
#                                  sig_L = 0.1,
#                                  h0 = 0.01,
#                                  beta = 0.5,  # change beta to see how quality of generated samples change
#                                  freq = 5,
#                                  model_sigma = .01)
# ## plot the progression and the final sample
# plot_synthesis(interm_Ys, sample)
# Out:
# Couldn't find program: 'false'

# %%
for n,p in denoiser.named_parameters():
    print(n,p)
# Out:
# conv_layers.0.weight Parameter containing:
# tensor([[[[ 7.2785e-02,  6.2441e-02,  8.7913e-02],
#           [ 5.3149e-01,  4.1510e-01,  4.1825e-01],
#           [ 4.5752e-01,  4.7675e-01,  3.7617e-01]],
#
#          [[-6.6980e-01, -5.3757e-01, -5.6338e-01],
#           [-2.7567e-01, -1.1581e-01, -3.0291e-01],
#           [-4.4513e-01, -1.6920e-01, -4.3576e-01]],
#
#          [[-4.3869e-01, -4.0428e-01, -3.9464e-01],
#           [-1.0683e-01, -9.4442e-02, -1.3378e-01],
#           [-2.7289e-01, -4.3268e-02, -1.5447e-01]]],
#
#
#         [[[-1.7534e-01,  3.7898e-02, -1.4160e-01],
#           [ 1.1042e-02,  1.0610e+00, -4.4600e-02],
#           [ 1.6151e-01, -1.4911e+00,  5.6766e-01]],
#
#          [[-1.5579e-01, -6.4053e-01,  2.6649e-01],
#           [-2.2573e-01, -1.4931e-01,  1.5631e-01],
#           [ 3.3888e-01,  1.3182e+00, -9.1057e-01]],
#
#          [[ 1.4408e-01,  4.2974e-01, -3.1420e-01],
#           [ 5.8807e-02, -6.5769e-01, -7.2643e-02],
#           [-5.1550e-01,  4.1452e-01,  5.1571e-01]]],
#
#
#         [[[-7.6844e-01,  1.2265e-01, -4.7164e-01],
#           [ 2.2141e-01,  4.2526e-01,  9.1082e-03],
#           [ 4.4220e-01,  1.6378e+00,  3.4529e-01]],
#
#          [[-8.6843e-04, -8.8157e-01,  3.6567e-01],
#           [-1.2794e+00, -6.8734e-03, -3.0759e-01],
#           [-9.7727e-02,  3.7745e-01,  2.6650e-01]],
#
#          [[ 3.6410e-01,  1.1114e+00,  1.9343e-01],
#           [-7.6271e-01, -1.4757e+00,  2.6920e-01],
#           [ 2.8791e-01, -6.8262e-01,  3.0062e-01]]],
#
#
#         ...,
#
#
#         [[[-2.3307e-01, -1.3077e-01, -1.7285e-01],
#           [ 1.3109e-01,  4.1560e-01,  1.2727e-01],
#           [-8.2206e-04, -3.0431e-04, -1.4559e-03]],
#
#          [[-1.8470e-01, -2.3663e-01, -1.3941e-01],
#           [ 1.6657e-01,  4.3249e-01,  1.2615e-01],
#           [ 1.1735e-03,  2.0296e-03,  1.4902e-03]],
#
#          [[-1.7497e-01, -2.3476e-01, -1.9551e-01],
#           [ 1.5353e-01,  4.5149e-01,  6.8456e-02],
#           [ 5.2298e-04,  3.5576e-04,  3.7849e-05]]],
#
#
#         [[[-1.9988e-01, -5.9431e-01, -9.5331e-01],
#           [ 7.0871e-01,  6.9314e-01,  1.6868e-01],
#           [-4.7497e-01,  8.2822e-02,  1.1240e-01]],
#
#          [[-3.0304e-01, -3.1704e-01,  2.1983e-01],
#           [ 1.4624e-01, -1.8036e-02, -9.9779e-01],
#           [ 1.0298e+00, -5.4269e-01,  1.5904e-01]],
#
#          [[ 2.5233e-01,  3.3992e-01,  6.3861e-01],
#           [-9.3905e-01,  2.0076e-01,  7.8729e-01],
#           [-6.5933e-01, -7.5384e-02,  3.1293e-02]]],
#
#
#         [[[ 2.6078e-01,  2.7989e-01, -2.4170e-01],
#           [ 2.6489e-01,  3.6628e-01, -1.4196e-01],
#           [-1.3417e-01, -1.2449e-01, -4.6170e-01]],
#
#          [[ 4.5188e-01,  5.2525e-01,  5.6568e-02],
#           [ 3.7718e-01,  4.7309e-01,  6.6976e-02],
#           [ 3.7321e-02,  1.0952e-01, -1.7920e-01]],
#
#          [[-4.0099e-01, -2.7566e-01, -5.4829e-01],
#           [-3.9686e-01, -2.6861e-01, -5.5266e-01],
#           [-6.5310e-01, -5.2872e-01, -6.9617e-01]]]], requires_grad=True)
# conv_layers.1.weight Parameter containing:
# tensor([[[[ 1.3246,  0.0049, -0.5256],
#           [ 1.1179, -0.2848, -1.3319],
#           [ 1.6193,  0.4089,  0.1217]],
#
#          [[-0.2325, -0.3159, -0.1829],
#           [ 0.2500,  0.4915,  0.4633],
#           [ 0.6297,  0.6238,  1.4399]],
#
#          [[ 0.4950, -1.1614, -0.7081],
#           [ 0.2251, -1.1492, -0.9859],
#           [ 0.9575, -0.4613,  0.0041]],
#
#          ...,
#
#          [[-0.2931, -0.2267,  0.0043],
#           [ 0.1171,  0.2039,  0.1460],
#           [ 0.2242, -0.0825,  0.1867]],
#
#          [[-0.8246,  0.1528, -0.1110],
#           [-0.2042,  0.1125, -0.1566],
#           [ 0.0859,  0.1899,  0.5373]],
#
#          [[ 0.8800, -0.1114,  0.2495],
#           [ 1.0167, -0.1402, -0.1821],
#           [ 0.7693,  0.3705,  0.4074]]],
#
#
#         [[[ 0.3685,  0.3439,  0.6457],
#           [-0.4321, -0.7181,  0.1250],
#           [-0.0717,  0.0256,  0.4016]],
#
#          [[ 0.0527, -0.0083, -0.2960],
#           [ 0.5094, -0.0444,  0.0089],
#           [ 0.5777,  0.5490,  0.2057]],
#
#          [[-0.3651, -0.2646, -0.5234],
#           [-0.5424, -0.2119, -1.0587],
#           [-0.3461, -0.3722,  0.0838]],
#
#          ...,
#
#          [[ 0.0923,  0.2768, -0.2639],
#           [ 0.0633,  0.2343,  0.0623],
#           [-1.0112, -0.2424, -0.2793]],
#
#          [[ 0.2752,  0.2393, -0.2589],
#           [ 0.1080, -0.6303, -0.5114],
#           [ 0.6952,  0.2927,  0.2778]],
#
#          [[-0.0353, -0.6894,  0.1679],
#           [-0.6058, -1.2854, -0.5593],
#           [-0.0374, -0.1196,  0.1777]]],
#
#
#         [[[ 0.0685, -0.1991,  0.0749],
#           [ 0.2833, -0.7145, -0.0903],
#           [ 1.1728,  0.9180,  0.8576]],
#
#          [[-0.2371,  0.5975,  0.1961],
#           [ 0.0258, -0.0404,  0.5312],
#           [-0.2871,  0.0141, -0.1666]],
#
#          [[-0.5753,  0.1414,  0.4899],
#           [-0.5498, -0.5330,  0.2274],
#           [-0.4343, -0.4109, -0.3094]],
#
#          ...,
#
#          [[-0.1913, -0.0443, -0.3595],
#           [ 0.1607, -0.2790, -0.1469],
#           [ 0.2061,  0.8235,  0.1952]],
#
#          [[ 0.1427, -0.0274,  0.6847],
#           [ 0.3214,  0.4527,  0.3393],
#           [ 0.1179, -0.2806,  0.0279]],
#
#          [[ 0.5356, -0.2166, -0.1176],
#           [-0.3382, -0.4424, -0.2412],
#           [-0.5116,  0.0970,  0.1579]]],
#
#
#         ...,
#
#
#         [[[-0.6656, -1.0036, -1.4762],
#           [ 0.1290, -0.4585, -1.3477],
#           [ 1.0527,  0.5529, -0.4034]],
#
#          [[-0.3196,  0.4552,  0.0609],
#           [-0.1352,  1.0412,  0.9561],
#           [ 0.0559,  0.6862,  1.0019]],
#
#          [[ 0.0273,  0.5927, -0.3306],
#           [ 0.1113,  0.0820, -0.0200],
#           [ 0.4906,  0.3046, -0.0462]],
#
#          ...,
#
#          [[-0.1222, -0.4398, -0.5620],
#           [ 0.6647,  0.0049, -0.0531],
#           [ 0.0796, -0.1576, -0.1485]],
#
#          [[-0.4515,  0.6759,  0.9696],
#           [ 0.0254,  0.9639,  0.7975],
#           [-0.4225,  0.3327,  0.6935]],
#
#          [[ 0.2532, -0.6393, -0.4697],
#           [ 1.1538,  0.6171, -0.2465],
#           [ 0.5241,  0.0951, -0.3188]]],
#
#
#         [[[-0.2228, -0.2715, -0.5033],
#           [ 0.2030,  0.2884,  0.0861],
#           [ 0.6510,  0.4651,  0.1497]],
#
#          [[ 0.3067,  0.5587,  0.7219],
#           [ 0.3514,  0.3087,  0.4941],
#           [-0.1851, -0.2027, -0.3232]],
#
#          [[-0.7289,  0.3834, -0.2892],
#           [-0.7505,  1.6003,  0.4012],
#           [ 0.4775,  0.3040,  0.4230]],
#
#          ...,
#
#          [[-0.3021,  0.0585, -0.0788],
#           [-0.0040, -0.1769,  0.1684],
#           [-0.3590, -0.1503, -0.0549]],
#
#          [[ 0.4892,  1.0195,  0.4125],
#           [ 0.3975,  0.2689, -0.1919],
#           [-0.5597,  0.2569, -0.4637]],
#
#          [[-0.2308,  0.1351, -0.3119],
#           [-0.0345,  0.6567,  0.8027],
#           [-0.0848,  0.7465,  1.0713]]],
#
#
#         [[[ 1.5530,  0.1198,  0.1322],
#           [ 0.4374, -1.7073, -0.8315],
#           [ 2.0328, -0.3666,  0.3445]],
#
#          [[-0.3811,  0.1958,  0.1001],
#           [-0.0878,  0.0720,  0.3807],
#           [ 0.1838,  0.3240,  0.1676]],
#
#          [[ 0.1628, -0.3215, -0.0988],
#           [-0.1489, -0.3711,  0.0813],
#           [ 0.0795, -0.1543,  0.1091]],
#
#          ...,
#
#          [[-0.7583, -0.5320, -1.0888],
#           [-0.5658, -0.7152, -0.3718],
#           [-1.1092, -1.2961, -1.1690]],
#
#          [[ 0.0647, -0.0484,  0.2127],
#           [ 0.2934,  0.2264,  0.2761],
#           [ 0.3647, -0.1764,  0.3694]],
#
#          [[-0.7936, -0.6948,  0.0445],
#           [ 0.1257,  0.1688,  0.3373],
#           [ 0.0750, -0.0396,  0.3786]]]], requires_grad=True)
# conv_layers.2.weight Parameter containing:
# tensor([[[[ 1.3379e+00,  1.9577e+00,  7.3177e-01],
#           [ 3.8445e-01,  5.0478e-01, -1.8279e-01],
#           [-4.5815e-01, -1.3421e+00, -1.9187e+00]],
#
#          [[-1.3155e-01,  1.1568e-01, -1.4381e+00],
#           [-1.0914e-01,  3.9007e-02, -2.1925e-01],
#           [ 5.8162e-01, -8.9603e-01, -1.3239e-01]],
#
#          [[-3.4971e-01, -8.8325e-02, -2.6508e-01],
#           [-8.1140e-01,  2.0606e-01, -1.4852e-01],
#           [-6.1946e-01,  4.0208e-01,  4.0203e-01]],
#
#          ...,
#
#          [[ 6.4046e-01,  1.0102e+00,  3.6320e-01],
#           [-5.5351e-01, -4.3705e-01, -1.1054e+00],
#           [-4.2539e-02, -6.0877e-01, -1.3794e+00]],
#
#          [[ 8.9103e-01,  1.4171e-01, -2.7522e-01],
#           [ 2.6501e-01, -3.4495e-01,  1.3338e-01],
#           [-4.6547e-01, -2.8019e-01,  6.1594e-01]],
#
#          [[-2.0090e-01,  4.8309e-01, -5.2104e-01],
#           [ 6.2954e-01, -3.4841e-01, -1.9046e+00],
#           [ 4.7890e-01, -3.5377e-01, -9.3843e-01]]],
#
#
#         [[[-2.8619e-01,  7.7001e-01,  3.6167e-01],
#           [ 5.9727e-01,  8.1869e-01,  4.0676e-01],
#           [-5.6218e-02, -2.9800e-01, -1.5274e-02]],
#
#          [[-1.1424e-01,  3.2202e-01, -4.4252e-01],
#           [ 1.2610e-01,  1.4151e-01,  3.8657e-03],
#           [-1.4222e-01,  1.0102e-01,  1.4734e-01]],
#
#          [[-5.7844e-01, -3.2598e-01, -5.1447e-01],
#           [-1.8173e-01, -4.0704e-01, -1.0966e+00],
#           [-6.6133e-01, -4.9225e-01,  1.5611e-02]],
#
#          ...,
#
#          [[-4.8156e-01, -5.1761e-02, -7.0103e-01],
#           [ 1.0886e-02, -4.4955e-01, -5.2080e-01],
#           [-1.0908e+00, -1.1263e+00, -4.4157e-01]],
#
#          [[ 1.4402e-01, -4.9645e-01,  1.1225e-01],
#           [ 7.6620e-01,  2.2645e-01,  5.5004e-01],
#           [ 1.6021e+00,  7.5524e-01,  6.3748e-01]],
#
#          [[ 1.3281e+00,  3.7605e-01,  7.7098e-01],
#           [ 8.7517e-01, -1.8259e-01,  3.4110e-01],
#           [ 7.2618e-01,  3.9357e-01,  5.8710e-01]]],
#
#
#           [-4.6180e-01,  8.0127e-03, -5.6927e-01],
#           [-8.4084e-01, -5.9291e-01, -9.7851e-01]],
#
#          [[-2.2172e-01, -3.9564e-02,  2.8088e-02],
#           [ 1.1530e-01,  5.4967e-01,  3.2273e-01],
#           [ 5.4440e-01,  5.1252e-01,  4.9137e-02]],
#
#          [[ 5.3054e-01,  2.4809e-01,  4.9848e-01],
#           [ 5.9618e-01, -1.7402e-02, -3.6319e-02],
#           [ 3.5769e-01,  1.4491e-01, -9.9378e-02]]],
#
#
#         [[[ 1.0766e-01,  2.1551e-01,  6.4766e-01],
#           [ 3.2216e-01,  4.8169e-01,  8.4203e-01],
#           [ 7.2211e-01,  4.1578e-01,  4.5892e-01]],
#
#          [[ 8.3206e-01,  1.1178e-01,  9.6391e-02],
#           [ 1.4010e+00,  1.4657e-01,  1.9818e-01],
#           [ 1.1936e+00,  6.2075e-01,  9.0589e-01]],
#
#          [[-4.2139e-01,  1.9728e-01,  5.5944e-01],
#           [-5.0988e-01,  1.6485e-03,  2.4187e-01],
#           [-7.8476e-01, -4.5119e-01, -1.3358e-01]],
#
#          ...,
#
#          [[ 2.5635e-01, -2.4224e-01,  1.3689e-01],
#           [ 4.0960e-01,  3.2971e-02,  1.6608e-01],
#           [-1.1992e-01, -2.4121e-01,  1.5347e-01]],
#
#          [[-9.4825e-02, -1.8220e-01, -3.7846e-01],
#           [-5.2770e-02,  1.8362e-01, -2.4968e-01],
#           [ 1.5334e-01,  7.5669e-02, -1.6440e-01]],
#
#          [[-3.2252e-01,  1.9646e-01,  1.3834e-01],
#           [-2.8062e-01,  6.2074e-02, -1.1584e-01],
#           [-6.1833e-01, -4.0961e-01, -7.6782e-01]]]], requires_grad=True)
# conv_layers.3.weight Parameter containing:
# tensor([[[[ 0.1303,  0.4089, -0.6610],
#           [ 0.1715, -0.0574, -0.3833],
#           [ 0.4410, -0.3773,  0.6553]],
#
#          [[-0.8190, -0.4504, -0.1526],
#           [-0.4329, -0.3996,  0.2753],
#           [-0.9290, -0.3105, -0.4736]],
#
#          [[ 0.8725,  0.7358, -0.3798],
#           [ 0.8988,  0.5827, -0.2007],
#           [ 0.9691,  0.8624,  0.3271]],
#
#          ...,
#
#          [[ 0.7307,  0.3060, -0.3217],
#           [-0.6545, -0.8317, -0.4414],
#           [-0.1025, -0.1366,  0.1104]],
#
#          [[-0.8849, -0.0338,  0.0641],
#           [ 0.1065,  0.3230,  0.1598],
#           [-0.1232,  0.4184,  0.3343]],
#
#          [[-0.7016,  0.1287,  0.1888],
#           [-0.7652, -0.5177, -0.6155],
#           [-0.5006, -0.1011, -0.5774]]],
#
#
#         [[[ 0.2327, -0.4718,  0.5188],
#           [-0.7598, -1.0892,  0.2876],
#           [-1.3175,  0.3019,  1.3314]],
#
#          [[ 0.4187, -0.9065, -0.7961],
#           [-0.9056, -1.1042, -0.6020],
#           [ 0.6246,  0.2896,  0.3246]],
#
#          [[-0.3668, -0.1780, -0.7277],
#           [-0.1080,  0.0944, -0.2144],
#           [ 0.1414, -0.3231, -0.4641]],
#
#          ...,
#
#          [[ 0.5232, -0.6504, -0.2634],
#           [-0.2477, -0.3355,  0.5866],
#           [-0.8458, -0.2040,  0.5076]],
#
#          [[ 0.2947,  0.3067,  0.4391],
#           [ 0.7147,  0.0306, -0.6206],
#           [ 0.3241, -0.1059, -0.3872]],
#
#          [[-0.3897, -0.2330, -0.0197],
#           [ 0.1761, -0.0897, -0.0684],
#           [ 0.4212,  0.2344, -0.1136]]],
#
#
#         [[[-0.0822, -0.6262, -1.0580],
#           [ 0.0668,  0.2641,  0.0947],
#           [ 0.2583,  0.7502, -0.2086]],
#
#          [[-0.4956, -0.5120, -0.0254],
#           [-0.0213, -0.4639, -0.1751],
#           [-0.1275, -0.5534, -0.5966]],
#
#          [[ 0.6378,  0.0623, -0.4408],
#           [ 0.3368, -0.0282, -0.6330],
#           [ 0.0667,  0.0937,  0.1005]],
#
#          ...,
#
#          [[-0.4541, -0.0122,  0.8363],
#           [-0.3996, -0.1915, -0.6987],
#           [ 0.1522,  0.0468, -1.3837]],
#
#          [[ 0.8441,  0.7455,  1.4427],
#           [ 0.2249,  0.4784,  0.7723],
#           [-0.4005, -0.0266,  0.7294]],
#
#          [[ 0.1972,  0.4381, -0.1560],
#           [ 0.0469,  0.4215,  0.1508],
#           [-0.4611, -0.2193,  0.1049]]],
#
#
#         ...,
#
#
#         [[[ 1.3324, -0.2681, -0.4980],
#           [ 0.4458, -0.4571, -0.0272],
#           [-0.7243, -0.9240,  0.4610]],
#
#          [[-0.1127,  0.4663,  0.2435],
#           [-0.1400,  0.4880,  0.6696],
#           [ 0.0871,  0.5546,  0.2725]],
#
#          [[ 0.0345, -0.3827, -1.1572],
#           [-0.2249, -0.1112, -1.0160],
#           [-0.4090, -0.6905, -1.1888]],
#
#          ...,
#
#          [[-1.1115, -0.8865, -0.3438],
#           [-0.1537, -0.0884,  0.3752],
#           [ 0.9589,  0.7505,  1.1814]],
#
#          [[-0.3727, -0.1660,  0.2654],
#           [-0.2962, -1.4685,  0.0409],
#           [ 0.4165,  0.1842,  0.1148]],
#
#          [[-0.0113,  0.0553,  0.3286],
#           [ 0.1089, -0.2542,  0.0273],
#           [ 0.6389,  0.2435,  0.1477]]],
#
#
#         [[[ 0.0526, -0.5172, -0.1868],
#           [-0.0083, -0.1988, -0.0630],
#           [-0.0327, -0.1513,  0.1184]],
#
#          [[-0.1313, -0.0840,  0.1259],
#           [-0.5422, -1.8286,  0.6958],
#           [-0.4773, -0.3401,  0.0085]],
#
#          [[ 0.2578, -0.2547, -0.4374],
#           [ 0.1791, -0.4771, -0.2679],
#           [ 0.0823,  0.7077,  0.1441]],
#
#          ...,
#
#          [[-0.7485, -0.4162, -0.3487],
#           [-0.4093, -0.1131,  0.1744],
#           [ 0.3435,  0.3670,  0.4337]],
#
#          [[ 0.3130,  0.2377,  0.3294],
#           [ 1.0639,  0.9317,  0.9051],
#           [ 0.7933,  1.1449,  0.4379]],
#
#          [[ 0.1975,  0.2356, -0.2533],
#           [-0.3033,  0.2659,  0.1308],
#           [-0.9187, -0.1685, -0.4472]]],
#
#
#         [[[-0.8126, -1.2658,  0.0090],
#           [ 0.8416, -0.3000, -0.3043],
#           [-0.4696, -0.5273, -0.5061]],
#
#          [[ 0.7356,  0.0735,  0.1192],
#           [ 0.1289, -0.0932,  0.3798],
#           [ 0.5475, -0.3243,  0.7173]],
#
#          [[-0.8760, -0.4974, -0.1321],
#           [-0.7726, -0.7531, -0.0196],
#           [-0.6967,  0.1124, -0.0577]],
#
#          ...,
#
#          [[-0.6679, -0.3747,  0.4135],
#           [-0.7241,  0.2026,  0.4548],
#           [ 0.1569,  0.4594,  0.6187]],
#
#          [[ 0.3262, -0.1080, -0.0610],
#           [ 0.2003, -1.0687,  0.0043],
#           [ 0.3161, -0.8735, -0.4235]],
#
#          [[ 0.4382,  0.5400,  0.7048],
#           [ 0.3207,  0.2067,  0.4060],
#           [ 0.3433, -0.0520,  0.4534]]]], requires_grad=True)
# conv_layers.4.weight Parameter containing:
# tensor([[[[ 3.6989e-01,  2.8942e-01,  1.0453e-01],
#           [ 7.8924e-01,  3.5254e-01, -7.1021e-01],
#           [-1.4460e+00, -8.4284e-01, -1.5073e+00]],
#
#          [[-5.2666e-01, -1.7937e+00,  4.0787e-01],
#           [-3.2521e-01, -1.2006e+00,  1.1737e+00],
#           [ 3.9529e+00, -9.2299e-01,  1.8276e+00]],
#
#          [[ 9.7480e-01, -9.5071e-01, -6.7519e-01],
#           [ 3.4315e-01, -2.0950e+00, -1.1522e+00],
#           [ 8.3869e-01, -6.7282e-01, -2.5281e-01]],
#
#          ...,
#
#          [[-8.7443e-02,  9.2746e-01,  1.2159e-01],
#           [ 1.7583e-01,  1.2893e-01, -3.9441e-01],
#           [-1.3679e+00, -6.5212e-01,  9.8094e-01]],
#
#          [[-4.8600e-01, -4.5613e-01, -5.5099e-01],
#           [-7.5325e-01, -9.5590e-01, -2.1711e-01],
#           [ 1.3171e-01,  1.9173e-01,  5.6896e-01]],
#
#          [[-4.1793e-04,  3.0827e-01,  4.6152e-01],
#           [-1.6834e-01, -2.6722e-01,  3.8697e-01],
#           [ 5.2475e-01, -1.1248e-01, -3.2800e-01]]],
#
#
#         [[[-3.4542e-01, -6.9522e-01, -9.8353e-01],
#           [ 1.1525e+00,  6.0007e-02,  1.4518e-01],
#           [ 6.3713e-01, -4.0804e-01, -4.8177e-01]],
#
#          [[-2.0035e-01,  1.3476e-01,  7.2519e-01],
#           [-9.2235e-01, -1.0463e+00,  3.9528e-01],
#           [ 1.9229e-01, -2.9812e-01,  1.0503e-01]],
#
#          [[-1.0337e+00, -1.5590e+00, -1.1036e+00],
#           [ 3.0291e-03, -1.6511e-01,  1.0758e+00],
#           [ 1.6488e-01, -7.9633e-01,  1.6427e+00]],
#
#          ...,
#
#          [[ 5.2910e-01,  1.7373e+00,  1.0108e-01],
#           [-5.2993e-01,  9.8392e-02,  4.0796e-01],
#           [-4.3553e-01,  9.1591e-02,  1.2053e+00]],
#
#           [-3.5137e-01, -3.0814e-01,  1.4510e+00],
#           [ 7.3944e-01,  8.3600e-01, -3.2679e-02]],
#
#          [[-1.6175e-01, -2.2881e-03,  6.7622e-01],
#           [ 3.0960e-01, -6.3720e-01, -1.2315e+00],
#           [-2.5594e-01, -1.3280e+00,  1.2393e-01]],
#
#          ...,
#
#          [[-3.4160e-01, -1.9176e+00, -3.0798e-01],
#           [ 1.8998e-01, -4.4386e-02, -3.6252e-01],
#           [ 8.3283e-01,  8.8604e-01,  6.7659e-01]],
#
#          [[ 2.9866e-01,  3.3892e-01,  9.1494e-02],
#           [-5.9264e-02, -3.1295e-01, -2.2256e-01],
#           [-6.1159e-01, -5.0149e-01, -1.2402e-01]],
#
#          [[ 4.1763e-01,  5.8202e-01,  5.2442e-01],
#           [ 4.9135e-01,  2.0770e-01, -4.5820e-01],
#           [-1.2552e-01, -8.1166e-01, -1.1341e+00]]],
#
#
#         [[[ 1.3678e+00, -3.5594e-01,  2.0878e-01],
#           [ 3.1915e-01,  1.7943e-01, -4.3536e-01],
#           [-2.4446e-01,  8.7247e-01, -3.1969e-01]],
#
#          [[ 2.2490e+00, -4.5435e-02, -1.2074e+00],
#           [ 5.5698e-01, -2.9773e-01, -5.4620e-01],
#           [-3.5463e-01,  3.6290e-02,  1.9708e-01]],
#
#          [[ 5.3850e-01, -1.6089e+00, -2.3292e-01],
#           [ 4.2283e-01, -1.0305e+00,  5.0690e-01],
#           [-6.3780e-01, -1.6892e+00, -6.4122e-01]],
#
#          ...,
#
#          [[ 3.6055e+00, -5.3585e-03, -2.1050e-01],
#           [-4.7019e-01,  4.1816e-01, -9.9607e-04],
#           [ 4.4381e-01, -1.9700e-01,  4.4920e-01]],
#
#          [[ 2.1979e-01,  1.3259e-01, -1.3917e-01],
#           [-3.9340e-01, -4.1605e-01, -3.0662e-01],
#           [-5.6013e-01,  3.9392e-01,  7.9531e-02]],
#
#          [[ 4.4611e-01, -5.3387e-01, -3.3156e-01],
#           [ 7.1016e-01, -1.1521e+00, -4.7370e-02],
#           [ 2.4968e-01,  1.9546e-01, -2.5122e-01]]]], requires_grad=True)
# conv_layers.5.weight Parameter containing:
# tensor([[[[ 5.3619e+00,  5.4737e+00,  5.0197e+00],
#           [-1.6937e+00, -3.2866e-01,  1.7680e+00],
#           [-4.2372e-01, -6.7831e-01,  1.0451e-01]],
#
#          [[ 1.8555e-01, -3.5255e-01,  8.6455e-01],
#           [-3.1304e-01, -5.5303e-01, -1.8551e-01],
#           [ 1.5554e-01,  1.6542e-01, -1.3748e+00]],
#
#          [[ 5.9553e-01,  1.5188e-01, -1.3512e-01],
#           [ 1.1980e+00,  8.1019e-01, -4.1514e-01],
#           [ 6.0568e-01,  5.3277e-01, -5.2045e-02]],
#
#          ...,
#
#          [[ 3.3700e+00,  6.7437e-01,  3.4638e+00],
#           [ 5.8077e-01,  2.3795e+00,  1.5024e+00],
#           [-8.7773e-01,  1.5029e-01,  9.2165e-01]],
#
#          [[-8.3375e-02,  3.6935e-01,  1.5835e-01],
#           [-2.0862e+00,  8.3952e-01, -3.3886e+00]],
#
#          [[ 1.1368e+00,  1.1059e+00, -1.7929e+00],
#           [ 2.1329e-01,  9.0141e-01, -4.8394e-01],
#           [ 4.5197e-01,  2.9950e-01, -6.8983e+00]],
#
#          ...,
#
#          [[ 1.1739e+00, -2.9712e-01,  7.8141e-02],
#           [ 1.4202e-02,  5.5302e-02,  3.5096e-01],
#           [ 6.1645e-01,  3.1655e-01,  8.4729e-01]],
#
#          [[ 1.7569e-01,  1.3684e+00,  9.2668e-01],
#           [-8.3799e-01, -3.7710e-01, -3.1827e-01],
#           [ 6.5682e-01,  1.1781e+00,  4.9143e-01]],
#
#          [[-2.7684e-01, -1.0932e-01,  2.1311e+00],
#           [-5.1058e-01, -1.5879e+00, -3.0911e+00],
#           [ 2.2445e-01, -2.1157e+00, -1.4105e+00]]],
#
#
#         [[[ 1.3625e+00, -1.3332e+00, -1.1403e+00],
#           [ 1.1514e+00, -3.1180e-01,  1.5580e-01],
#           [-2.2220e-01, -4.9763e-02,  5.2565e-03]],
#
#          [[ 9.8101e-01, -5.8265e-01,  1.5961e-01],
#           [-5.5839e-01,  1.9912e-01,  5.0657e-01],
#           [-5.7123e-01,  1.8965e-02,  1.5616e-01]],
#
#          [[ 7.6855e-01,  5.4654e-01, -2.4854e-01],
#           [ 1.4665e-01,  1.7944e-01,  5.0103e-01],
#           [ 4.5693e-01, -7.1480e-01,  1.4373e+00]],
#
#          ...,
#
#          [[-2.0047e+00, -2.2240e+00, -2.1780e+00],
#           [ 1.3592e+00, -4.6676e-01, -9.8976e-01],
#           [ 1.7272e-02,  5.7705e-03,  5.4215e-01]],
#
#          [[ 2.6437e+00, -4.8257e-01, -1.8098e-01],
#           [ 8.6318e-02,  2.5567e-01,  6.2430e-01],
#           [-3.1827e-01,  2.8054e-02,  4.5238e-02]],
#
#          [[ 8.0775e-01, -1.4693e+00,  2.1967e+00],
#           [-2.4107e-02, -3.0867e-01,  1.3504e-01],
#           [ 4.3128e-01,  5.5500e-01,  7.4981e-01]]],
#
#
#         [[[-1.5086e+00, -2.5369e+00, -2.0769e+00],
#           [-1.8957e+00, -2.0740e+00, -2.0068e+00],
#           [-1.7165e+00, -1.0060e-01,  7.0121e-01]],
#
#          [[-1.1070e+00, -5.0467e-01, -8.9241e-01],
#           [ 3.5935e-01,  1.0503e+00,  9.9980e-01],
#           [ 9.0275e-01,  1.8124e-01, -1.0099e+00]],
#
#          [[-1.0865e+00, -1.7966e+00, -8.4362e-01],
#           [-5.9022e-01, -1.7663e+00, -6.4275e-01],
#           [ 1.9057e+00, -3.3287e-01, -8.9525e-01]],
#
#          ...,
#
#          [[ 3.5475e-01,  1.2879e+00,  1.1946e-01],
#           [-2.3749e+00, -2.3682e+00, -2.4212e+00],
#           [ 3.9646e-01,  2.0787e-01, -1.2454e+00]],
#
#          [[ 2.5854e+00,  2.0310e+00,  1.0161e+00],
#           [ 2.0854e+00,  8.1950e-01,  1.3486e+00],
#           [ 2.9690e-01,  2.1364e-01, -2.1830e-02]],
#
#          [[ 1.7469e+00, -5.9020e-02, -1.4886e+00],
#           [ 3.4151e-01,  1.0947e+00,  1.2620e+00],
#           [-1.7639e-01, -2.6778e-01,  4.7579e-01]]]], requires_grad=True)
# conv_layers.6.weight Parameter containing:
# tensor([[[[-2.9068e-01,  6.5119e-01,  1.2640e+00],
#           [-1.3684e-01,  3.9663e-01,  1.5272e+00],
#           [ 8.1791e-01, -9.9977e-01,  9.4297e-02]],
#
#          [[ 1.7856e-01, -2.2298e-01, -2.0767e-01],
#           [-5.8281e-01, -1.2655e-01, -3.0264e-01],
#           [-1.0742e-01,  5.3904e-03,  4.3927e-01]],
#
#          [[-3.3805e-02, -1.7475e-02,  6.9650e-02],
#           [ 9.3684e-02,  8.6164e-02,  4.6549e-02],
#           [ 2.2873e-03,  6.2409e-02,  3.3462e-02]],
#
#          ...,
#
#          [[ 4.9162e+00,  1.0311e+00,  1.5832e+00],
#           [-1.8640e-01,  5.7152e-01,  7.1331e-01],
#           [ 7.5250e-01,  7.9204e-01, -2.8434e-01]],
#
#          [[ 4.2144e-01,  2.1061e-01, -2.0532e+00],
#           [ 1.8275e-01,  6.9277e-01, -9.9679e-01],
#           [ 7.6334e-01,  5.3240e-01,  2.0869e+00]],
#
#          [[ 1.4375e-01,  5.6630e-01,  2.5872e-01],
#           [-8.0568e-01,  1.0758e+00, -1.6853e+00],
#           [-4.5298e-01, -1.7121e+00,  2.4939e-01]]],
#
#
#         [[[ 1.0075e+00, -1.9284e+00,  1.6530e+00],
#           [ 1.4740e+00, -2.1160e+00, -3.8567e-03],
#           [ 1.2108e-01,  3.9494e-01, -4.6356e-01]],
#
#          [[-1.2307e-01,  1.4406e-01,  2.7867e-01],
#           [-5.6312e-01, -4.8765e-01,  1.6478e-01],
#           [ 6.1836e-01,  6.1556e-01,  8.4673e-01]],
#
#          [[ 5.0829e-02,  6.5211e-02,  2.4817e-02],
#           [-9.8052e-02,  2.3461e-02, -4.5772e-02],
#           [ 1.2870e-02,  6.2932e-02,  1.7987e-02]],
#
#          ...,
#
#          [[-3.0819e+00, -1.3326e+00, -1.3072e-01],
#           [-4.0791e+00, -1.4118e+00,  7.4854e-02],
#           [ 9.9010e-01,  4.2229e-01,  6.0229e-01]],
#
#          [[ 3.7214e-01,  1.1622e-01,  6.4484e-01],
#           [-5.1536e-01, -8.1224e-02, -5.0251e-01],
#           [ 3.0290e-01,  3.9927e-01, -5.7330e-01]],
#
#          [[-1.5879e+00,  1.4260e+00, -1.3848e+00],
#           [-4.2197e-01,  9.3414e-01,  3.6811e-01],
#           [-1.6108e-01, -4.8683e-01,  1.6759e-01]]],
#
#
#         [[[ 7.1111e-01,  3.0967e-01,  1.5553e+00],
#           [ 1.2713e+00,  1.7934e-01, -7.2949e-01],
#           [-1.0117e+00,  3.7015e-01, -9.6301e-01]],
#
#          [[-1.1361e-01, -1.7384e-01, -1.2302e+00],
#           [ 1.7627e-01, -4.4705e-01, -1.6998e+00],
#
#          [[ 3.6389e-01, -8.2611e-02,  5.1585e-01],
#           [-7.1924e-02, -7.5213e-01, -2.2028e-01],
#           [ 4.5708e-02,  5.4065e-01,  1.5446e+00]]],
#
#
#         [[[ 5.5302e-01, -1.0912e+00, -1.2843e+00],
#           [-7.3989e-04,  1.2982e-01,  1.2904e+00],
#           [-1.6262e-01,  2.1526e-01,  1.4032e-01]],
#
#          [[-6.8329e-01, -5.2211e-01, -2.8630e-01],
#           [-4.7414e-01, -3.5639e-01,  6.6739e-01],
#           [ 5.3433e-02,  3.1114e-01,  3.4396e-01]],
#
#          [[ 7.9227e-02,  7.7432e-02, -8.1329e-02],
#           [-6.5728e-03,  4.1512e-02, -1.4505e-02],
#           [ 9.8719e-02,  9.4450e-02,  9.0256e-02]],
#
#          ...,
#
#          [[ 4.6139e+00,  2.2530e+00,  2.4138e+00],
#           [ 3.3372e-02,  7.4830e-01,  5.6834e-01],
#           [-5.0019e-01,  5.8038e-02,  1.1976e-01]],
#
#          [[-1.7034e-01, -1.1669e-02, -1.8805e+00],
#           [ 8.9591e-01,  5.2432e-01,  3.2616e-01],
#           [-5.8039e-02, -8.5807e-01,  1.3042e+00]],
#
#          [[ 4.7906e-01,  4.8239e-01,  3.7591e-01],
#           [-1.0331e-01,  9.1992e-01,  5.6426e-01],
#           [-2.7278e-01,  4.8365e-01, -3.2675e-01]]]], requires_grad=True)
# conv_layers.7.weight Parameter containing:
# tensor([[[[-1.8429e+00, -6.9452e-01, -6.8940e-01],
#           [ 4.3549e-01,  1.0279e+00,  2.9423e+00],
#           [-1.7436e+00, -1.1482e+00, -1.7069e-01]],
#
#          [[-5.6046e-01, -1.3313e+00,  1.1888e+00],
#           [-9.3259e-01,  2.3958e-01, -1.2598e+00],
#           [-8.8904e-01,  4.8441e+00,  8.4680e-01]],
#
#          [[ 1.8659e+00, -4.7547e-01,  9.6415e-02],
#           [ 1.9986e+00, -9.9739e-01, -5.9857e-03],
#           [ 2.2315e+00, -8.4808e-01,  7.9378e-02]],
#
#          ...,
#
#          [[-1.1837e+00,  2.5552e-01, -2.4332e-01],
#           [-3.6228e-01,  1.8337e+00,  1.0924e+00],
#           [-1.7203e+00,  8.0997e-01, -1.8366e+00]],
#
#          [[ 3.2496e-01,  3.5231e-01,  2.9697e-01],
#           [ 4.5634e-01,  4.3197e-01, -1.3003e-01],
#           [ 7.4232e-02, -1.2023e-01, -5.5554e-01]],
#
#          [[-1.2888e-01, -9.1670e-01,  6.2401e-01],
#           [ 1.9823e+00,  9.8005e-01,  2.4607e-01],
#           [-2.0320e+00, -1.2045e+00, -1.5868e+00]]],
#
#
#         [[[ 1.0412e+00,  3.9401e-01, -4.6398e-01],
#           [-2.0828e+00, -1.4734e+00, -2.0582e+00],
#           [ 2.4862e-01,  4.5740e-01,  2.9959e+00]],
#
#          [[-9.1499e-01,  1.0299e+00,  8.1187e-02],
#           [ 3.3908e-01,  5.0454e-02, -2.3075e-01],
#           [-3.8312e-01, -1.9293e+00, -1.2426e-02]],
#           [ 3.0660e-02,  2.7770e-02, -1.6414e-02]],
#
#          ...,
#
#          [[ 5.1953e-02, -4.4544e-03, -2.0380e-02],
#           [ 6.5155e-02, -2.4535e-02, -3.9526e-02],
#           [ 2.0314e-02,  5.4958e-02,  1.0415e-01]],
#
#          [[ 6.7235e-02, -3.5316e-02,  2.7833e-02],
#           [ 4.7374e-03,  1.1578e-01,  9.5290e-02],
#           [ 6.0524e-04, -1.4168e-02,  6.5358e-02]],
#
#          [[-1.0569e-01,  1.9466e-02, -1.5262e-02],
#           [ 6.6128e-02,  4.7789e-02,  1.4895e-01],
#           [ 5.6957e-02,  2.7071e-02, -8.0525e-04]]]], requires_grad=True)
# conv_layers.9.weight Parameter containing:
# tensor([[[[-7.0585e-02, -6.7106e-02,  5.2426e-02],
#           [ 3.8388e-02,  6.1811e-02, -3.2515e-02],
#           [-1.5137e-02,  9.9832e-02,  3.5271e-02]],
#
#          [[ 1.9909e-01,  8.6958e-01, -1.4921e-01],
#           [-2.5350e-01,  3.2313e-01, -1.1738e+00],
#           [-1.4473e-01,  2.8878e-01, -9.5614e-01]],
#
#          [[-1.9764e-01, -1.4613e-02,  5.7776e-01],
#           [ 1.7603e-01,  2.9317e-01,  1.1492e+00],
#           [-2.3501e+00,  2.9651e-01,  5.6155e-01]],
#
#          ...,
#
#          [[ 9.1051e-02,  6.5784e-01, -3.6101e-01],
#           [-6.1331e-01, -2.6791e-01, -6.8495e-01],
#           [-4.5848e-01, -7.2907e-01, -8.8993e-01]],
#
#          [[ 1.2703e-01, -9.7346e-03, -5.5427e-01],
#           [ 9.4467e-01,  2.2501e-01,  1.4313e-01],
#           [ 1.8882e-01,  3.2349e-01, -1.5684e-01]],
#
#          [[ 4.8241e-02,  6.5447e-03,  1.1757e-02],
#           [-4.6550e-02,  1.1931e-01,  1.4014e-02],
#           [-4.9029e-02,  9.5414e-02,  1.2589e-01]]],
#
#
#         [[[ 3.6955e-02, -5.6936e-02, -1.2805e-02],
#           [-1.7087e-02,  2.3623e-02,  4.6092e-02],
#           [ 1.2713e-01, -2.1383e-02, -3.2002e-03]],
#
#          [[ 6.5935e-01,  3.1657e-02, -3.5249e-01],
#           [-4.6374e-02, -2.4464e-01, -7.3499e-01],
#           [ 2.5534e-01,  4.3602e-01,  2.4926e-01]],
#
#          [[-5.3801e-01, -1.6304e-01, -4.8852e-01],
#           [ 2.3236e+00,  2.3152e+00,  6.4098e-01],
#           [ 4.1238e+00, -2.1903e+00, -1.8546e+00]],
#
#          ...,
#
#          [[ 4.6023e-01,  8.9870e-01,  4.5319e-01],
#           [-1.8839e-01,  2.7560e-02,  1.4639e-01],
#           [ 1.2639e-01,  2.3351e-01,  2.7030e-01]],
#
# ...
#
#          [[ 0.3090]],
#
#          [[ 0.2986]],
#
#          [[ 0.2893]],
#
#          [[ 0.2677]],
#
#          [[ 0.7963]],
#
#          [[-0.4483]],
#
#          [[-0.4904]],
#
#          [[-0.5105]],
#
#          [[-0.0135]],
#
#          [[-0.4849]],
#
#          [[ 0.6242]],
#
#          [[-0.3320]],
#
#          [[ 0.0247]],
#
#          [[-0.0038]],
#
#          [[ 0.4389]],
#
#          [[ 0.4078]],
#
#          [[ 0.3304]],
#
#          [[ 0.3294]],
#
#          [[ 0.7279]],
#
#          [[ 0.3409]],
#
#          [[-0.7593]],
#
#          [[ 0.5043]],
#
#          [[ 1.0264]],
#
#          [[-0.3206]],
#
#          [[ 0.3116]],
#
#          [[ 0.4704]],
#
#          [[ 0.2807]],
#
#          [[-0.6489]],
#
#          [[ 0.3757]],
#
#          [[ 0.4197]],
#
#          [[-0.2935]],
#
#          [[-0.5376]],
#
#          [[-0.4422]],
#
#          [[ 0.8374]],
#
#          [[ 0.3100]],
#
#          [[ 0.0028]],
#
#          [[ 0.2512]],
#
#          [[-0.0315]],
#
#          [[ 0.2822]],
#
#          [[ 0.4777]],
#
#          [[ 0.5431]],
#
#          [[ 0.4762]]]], requires_grad=True)
# gammas.9 Parameter containing:
# tensor([[[[-0.4541]],
#
#          [[ 0.2294]],
#
#          [[ 0.3303]],
#
#          [[-0.3054]],
#
#          [[ 0.6746]],
#
#          [[ 1.0520]],
#
#          [[ 0.4424]],
#
#          [[-0.0189]],
#
#          [[ 0.5160]],
#
#          [[-0.2209]],
#
#          [[-0.2903]],
#
#          [[ 0.4548]],
#
#          [[ 0.5978]],
#
#          [[-0.9973]],
#
#          [[-0.3552]],
#
#          [[-0.3961]],
#
#          [[-0.0041]],
#
#          [[ 0.2634]],
#
#          [[-0.0299]],
#
#          [[ 1.2339]],
#
#          [[-0.2786]],
#
#          [[ 0.3252]],
#
#          [[ 0.1442]],
#
#          [[ 0.4363]],
#
#          [[ 0.8195]],
#
#          [[-0.0039]],
#
#          [[ 0.2579]],
#
#          [[ 0.0304]],
#
#          [[ 0.2928]],
#
#          [[ 0.4317]],
#
#          [[ 0.3706]],
#
#          [[ 0.4435]],
#
#          [[-0.3380]],
#
#          [[-1.0421]],
#
#          [[ 0.6317]],
#
#          [[-0.0079]],
#
#          [[ 0.4401]],
#
#          [[ 0.9924]],
#
#          [[-0.0016]],
#
#          [[-0.4571]],
#
#          [[-0.8486]],
#
#          [[ 0.3197]],
#
#          [[-0.4868]],
#
#          [[-0.4093]],
#
#          [[ 0.4039]],
#
#          [[ 0.3192]],
#
#          [[ 0.5307]],
#
#          [[-0.0234]],
#
#          [[ 0.9947]],
#
#          [[-0.4198]],
#
#          [[-0.4576]],
#
#          [[ 0.1468]],
#
#          [[-0.4844]],
#
#          [[-0.2015]],
#
#          [[-0.3950]],
#
#          [[-0.2988]],
#
#          [[ 0.3690]],
#
#          [[ 0.0031]],
#
#          [[ 0.7109]],
#
#          [[-0.5204]],
#
#          [[-0.0305]],
#
#          [[-0.0239]],
#
#          [[ 0.5778]],
#
#          [[-0.2776]]]], requires_grad=True)
# gammas.10 Parameter containing:
# tensor([[[[ 2.7364e-01]],
#
#          [[-2.4975e-01]],
#
#          [[ 4.4570e-01]],
#
#          [[-3.4000e-01]],
#
#          [[ 2.4822e-01]],
#
#          [[-3.7327e-01]],
#
#          [[-3.5489e-01]],
#
#          [[-3.9413e-01]],
#
#          [[-7.0553e-01]],
#
#          [[ 3.3557e-01]],
#
#          [[-6.3980e-01]],
#
#          [[-2.7162e-01]],
#
#          [[ 4.6773e-01]],
#
#          [[-9.5725e-01]],
#
#          [[ 2.8208e-01]],
#
#          [[ 7.2655e-01]],
#
#          [[-7.1794e-03]],
#
#          [[ 2.9408e-01]],
#
#          [[-4.1902e-01]],
#
#          [[-7.0613e-01]],
#
#          [[-1.5204e-03]],
#
#          [[ 1.9185e-03]],
#
#          [[ 3.1233e-01]],
#
#          [[-3.2619e-01]],
#
#          [[ 2.4130e-01]],
#
#          [[ 3.2990e-01]],
#
#          [[-2.8937e-01]],
#
#          [[-3.1957e-01]],
#
#          [[-2.8747e-01]],
#
#          [[ 5.3347e-01]],
#
#          [[-5.9561e-01]],
#
#          [[ 4.0297e-03]],
#
#          [[-5.5489e-01]],
#
#          [[-6.6077e-01]],
#
#          [[ 3.5115e-01]],
#
#          [[ 4.7503e-03]],
#
#          [[ 7.5988e-01]],
#
#          [[ 5.1154e-01]],
#
#          [[ 2.9148e-02]],
#
#          [[ 2.9013e-01]],
#
#          [[ 4.7838e-01]],
#
#          [[ 2.7297e-01]],
#
#          [[-5.6102e-01]],
#
#          [[-3.6295e-01]],
#
#          [[-3.4018e-01]],
#
#          [[-5.5333e-01]],
#
#          [[ 1.1035e-02]],
#
#          [[ 6.6812e-01]],
#
#          [[ 2.8039e-01]],
#
#          [[-9.2707e-01]],
#
#          [[ 5.6042e-01]],
#
#          [[-1.5253e-04]],
#
#          [[ 4.5478e-01]],
#
#          [[-4.1190e-03]],
#
#          [[-3.4630e-01]],
#
#          [[-7.8142e-03]],
#
#          [[-2.6814e-02]],
#
#          [[ 4.8198e-02]],
#
#          [[-2.4257e-01]],
#
#          [[ 8.9493e-03]],
#
#          [[ 2.5234e-01]],
#
#          [[ 1.8888e-01]],
#
#          [[-4.9838e-01]],
#
#          [[-3.1321e-01]]]], requires_grad=True)
# gammas.11 Parameter containing:
# tensor([[[[ 3.7605e-01]],
#
#          [[-7.6775e-01]],
#
#          [[ 1.1734e+00]],
#
#          [[ 1.3735e-01]],
#
#          [[ 4.9058e-01]],
#
#          [[ 6.4683e-01]],
#
#          [[-5.5558e-01]],
#
#          [[ 1.6695e-01]],
#
#          [[ 9.4681e-01]],
#
#          [[-2.1731e-01]],
#
#          [[ 3.7479e-01]],
#
#          [[-7.2120e-01]],
#
#          [[-3.3691e-03]],
#
#          [[ 4.4291e-01]],
#
#          [[-2.7515e-01]],
#
#          [[-5.8815e-01]],
#
#          [[ 5.7556e-01]],
#
#          [[ 2.4352e-01]],
#
#          [[-3.4049e-01]],
#
#          [[-3.7250e-01]],
#
#          [[-4.6721e-01]],
#
#          [[ 3.0617e-01]],
#
#          [[-3.1422e-01]],
#
#          [[ 6.9350e-01]],
#
#          [[ 3.9786e-01]],
#
#          [[ 3.0419e-01]],
#
#          [[ 3.1234e-01]],
#
#          [[ 2.3631e-01]],
#
#          [[-5.5658e-01]],
#
#          [[ 4.3120e-01]],
#
#          [[ 2.2802e-01]],
#
#          [[ 1.7559e-03]],
#
#          [[ 1.3979e-01]],
#
#          [[ 2.7441e-01]],
#
#          [[ 8.7332e-01]],
#
#          [[-4.3815e-01]],
#
#          [[-6.0204e-01]],
#
#          [[ 2.5991e-01]],
#
#          [[-2.8308e-01]],
#
#          [[-9.5274e-04]],
#
#          [[-2.2574e-01]],
#
#          [[ 9.6509e-01]],
#
#          [[-5.4267e-01]],
#
#          [[ 3.2871e-01]],
#
#          [[ 2.4947e-01]],
#
#          [[ 3.8328e-01]],
#
#          [[ 5.1330e-01]],
#
#          [[-1.8582e-02]],
#
#          [[ 2.9694e-01]],
#
#          [[-8.1392e-01]],
#
#          [[ 1.2050e+00]],
#
#          [[-5.5402e-01]],
#
#          [[-1.1297e+00]],
#
#          [[ 2.8579e-01]],
#
#          [[ 2.9300e-01]],
#
#          [[ 3.5627e-01]],
#
#          [[ 3.9015e-01]],
#
#          [[-6.0150e-01]],
#
#          [[ 3.1391e-02]],
#
#          [[-5.5075e-01]],
#
#          [[ 3.0183e-01]],
#
#          [[ 4.1652e-01]],
#
#          [[-4.5326e-01]],
#
#          [[ 2.4076e-01]]]], requires_grad=True)
# gammas.12 Parameter containing:
# tensor([[[[-5.6102e-01]],
#
#          [[-5.7576e-01]],
#
#          [[-4.2026e-01]],
#
#          [[ 2.0294e-02]],
#
#          [[ 6.5524e-01]],
#
#          [[ 1.9636e-02]],
#
#          [[-2.7121e-01]],
#
#          [[ 3.5485e-03]],
#
#          [[ 2.7154e-01]],
#
#          [[-4.1088e-01]],
#
#          [[ 5.6195e-01]],
#
#          [[ 7.0489e-01]],
#
#          [[ 2.9900e-01]],
#
#          [[-4.5699e-01]],
#
#          [[-1.4232e+00]],
#
#          [[-2.3197e-01]],
#
#          [[ 5.5686e-01]],
#
#          [[-5.9676e-01]],
#
#          [[ 5.9506e-01]],
#
#          [[ 4.0448e-01]],
#
#          [[-2.8119e-01]],
#
#          [[-2.8633e-01]],
#
#          [[-2.6007e-01]],
#
#          [[ 4.7012e-01]],
#
#          [[ 7.3627e-01]],
#
#          [[ 1.6515e-02]],
#
#          [[-4.5906e-01]],
#
#          [[-6.9380e-01]],
#
#          [[-6.6010e-01]],
#
#          [[-1.3146e-03]],
#
#          [[ 3.1838e-01]],
#
#          [[-4.3935e-01]],
#
#          [[ 5.1668e-01]],
#
#          [[ 2.8619e-01]],
#
#          [[ 4.4972e-01]],
#
#          [[-2.8241e-01]],
#
#          [[-3.1622e-01]],
#
#          [[-3.0327e-01]],
#
#          [[-2.6852e-01]],
#
#          [[ 3.3077e-01]],
#
#          [[ 4.6342e-01]],
#
#          [[-3.4401e-01]],
#
#          [[-1.1141e+00]],
#
#          [[ 1.0072e-01]],
#
#          [[-2.5839e-01]],
#
#          [[ 4.9669e-01]],
#
#          [[-3.5066e-01]],
#
#          [[ 5.3867e-01]],
#
#          [[ 5.9619e-01]],
#
#          [[ 4.1207e-01]],
#
#          [[-3.9023e-01]],
#
#          [[ 2.9470e-01]],
#
#          [[ 3.1571e-02]],
#
#          [[-3.4196e-01]],
#
#          [[ 2.8058e-01]],
#
#          [[ 7.4823e-03]],
#
#          [[ 8.4527e-01]],
#
#          [[ 5.5108e-01]],
#
#          [[ 1.1964e+00]],
#
#          [[ 4.0610e-01]],
#
#          [[ 1.0414e+00]],
#
#          [[ 1.5030e+00]],
#
#          [[-5.4953e-01]],
#
#          [[ 2.7948e-03]]]], requires_grad=True)
# gammas.13 Parameter containing:
# tensor([[[[ 0.2260]],
#
#          [[ 0.3344]],
#
#          [[-0.4136]],
#
#          [[-0.4365]],
#
#          [[-0.4574]],
#
#          [[-0.1590]],
#
#          [[-0.0278]],
#
#          [[ 0.2341]],
#
#          [[ 0.7002]],
#
#          [[-0.8239]],
#
#          [[-0.1913]],
#
#          [[-0.3725]],
#
#          [[-0.3520]],
#
#          [[ 0.0311]],
#
#          [[ 0.3734]],
#
#          [[-0.4565]],
#
#          [[ 0.6501]],
#
#          [[ 0.2197]],
#
#          [[-0.3975]],
#
#          [[ 0.4284]],
#
#          [[ 0.3580]],
#
#          [[ 0.7277]],
#
#          [[-0.3310]],
#
#          [[-0.2995]],
#
#          [[-1.0173]],
#
#          [[ 0.5519]],
#
#          [[ 0.3521]],
#
#          [[ 0.4807]],
#
#          [[ 0.7712]],
#
#          [[-0.2815]],
#
#          [[ 0.6771]],
#
#          [[ 0.2654]],
#
#          [[ 0.2841]],
#
#          [[ 0.4311]],
#
#          [[ 0.2744]],
#
#          [[ 0.3351]],
#
#          [[-0.2852]],
#
#          [[-0.0030]],
#
#          [[-0.2452]],
#
#          [[-1.7990]],
#
#          [[ 0.3019]],
#
#          [[ 0.7645]],
#
#          [[ 0.3006]],
#
#          [[-1.0448]],
#
#          [[-0.4442]],
#
#          [[ 0.4684]],
#
#          [[ 0.2758]],
#
#          [[ 0.2752]],
#
#          [[ 0.2517]],
#
#          [[-0.3071]],
#
#          [[ 0.3679]],
#
#          [[ 0.4102]],
#
#          [[ 0.5017]],
#
#          [[-0.5668]],
#
#          [[-0.3982]],
#
#          [[ 0.0132]],
#
#          [[-0.0041]],
#
#          [[ 0.3516]],
#
#          [[ 0.6152]],
#
#          [[ 1.9553]],
#
#          [[ 0.3228]],
#
#          [[ 0.8779]],
#
#          [[ 0.5695]],
#
#          [[-0.6637]]]], requires_grad=True)
# gammas.14 Parameter containing:
# tensor([[[[ 3.3634e-01]],
#
#          [[ 8.9199e-01]],
#
#          [[-3.0034e-02]],
#
#          [[-3.2619e-01]],
#
#          [[ 9.2261e-01]],
#
#          [[ 2.9169e-01]],
#
#          [[-6.6735e-01]],
#
#          [[-7.2334e-01]],
#
#          [[-3.9563e-01]],
#
#          [[-5.4515e-01]],
#
#          [[-7.5553e-01]],
#
#          [[-2.7573e-01]],
#
#          [[ 7.6713e-01]],
#
#          [[ 3.0429e-01]],
#
#          [[ 7.1156e-01]],
#
#          [[ 3.9921e-01]],
#
#          [[-7.8622e-01]],
#
#          [[ 3.0585e-01]],
#
#          [[ 3.7073e-01]],
#
#          [[ 4.7426e-01]],
#
#          [[ 4.9536e-01]],
#
#          [[-2.0833e-01]],
#
#          [[ 2.9076e-01]],
#
#          [[-4.5557e-01]],
#
#          [[-3.0449e-01]],
#
#          [[-8.8992e-01]],
#
#          [[-1.5304e-02]],
#
#          [[-1.5885e-02]],
#
#          [[-6.9934e-01]],
#
#          [[ 1.0147e+00]],
#
#          [[ 4.1543e-01]],
#
#          [[-7.2561e-02]],
#
#          [[ 3.9827e-01]],
#
#          [[ 6.2870e-01]],
#
#          [[ 2.9449e-01]],
#
#          [[ 2.5680e+00]],
#
#          [[ 4.2811e-01]],
#
#          [[-2.5821e-01]],
#
#          [[-6.5342e-01]],
#
#          [[ 5.7432e-01]],
#
#          [[-2.9759e-01]],
#
#          [[-4.7610e-01]],
#
#          [[ 3.3720e-01]],
#
#          [[ 5.3122e-01]],
#
#          [[-1.0480e+00]],
#
#          [[-5.6457e-03]],
#
#          [[ 1.1090e-03]],
#
#          [[-4.9719e-01]],
#
#          [[ 4.2188e-01]],
#
#          [[-5.1577e-01]],
#
#          [[ 2.7667e-01]],
#
#          [[-3.0404e-01]],
#
#          [[ 2.2804e-01]],
#
#          [[-1.8132e-03]],
#
#          [[ 3.6576e-01]],
#
#          [[ 5.3318e-01]],
#
#          [[-8.7667e-01]],
#
#          [[ 5.4636e-03]],
#
#          [[ 3.7364e-01]],
#
#          [[ 6.8804e-05]],
#
#          [[-1.0402e+00]],
#
#          [[-2.9056e-01]],
#
#          [[ 3.0975e-03]],
#
#          [[-5.0128e-01]]]], requires_grad=True)
# gammas.15 Parameter containing:
# tensor([[[[ 5.5191e-01]],
#
#          [[ 1.0401e+00]],
#
#          [[ 2.6553e-01]],
#
#          [[-3.9935e-01]],
#
#          [[ 5.4943e-01]],
#
#          [[-2.0381e-02]],
#
#          [[-1.3709e-01]],
#
#          [[ 2.6474e-01]],
#
#          [[-5.1451e-01]],
#
#          [[ 3.1667e-02]],
#
#          [[ 2.2346e-01]],
#
#          [[-4.0905e-01]],
#
#          [[ 5.1475e-01]],
#
#          [[-8.0710e-01]],
#
#          [[ 6.9378e-04]],
#
#          [[-2.3864e-01]],
#
#          [[-1.6558e-01]],
#
#          [[-3.3974e-01]],
#
#          [[ 3.2293e-01]],
#
#          [[ 4.8464e-01]],
#
#          [[ 3.3482e-02]],
#
#          [[ 3.4234e-01]],
#
#          [[ 2.8162e-01]],
#
#          [[-2.6136e-01]],
#
#          [[-7.2340e-01]],
#
#          [[ 1.0979e+00]],
#
#          [[ 2.8428e-01]],
#
#          [[ 1.6638e-02]],
#
#          [[-8.2817e-01]],
#
#          [[-2.7914e-01]],
#
#          [[ 2.9477e-01]],
#
#          [[ 1.9625e-01]],
#
#          [[-3.3373e-01]],
#
#          [[ 2.9759e-01]],
#
#          [[ 4.0486e-01]],
#
#          [[ 2.3034e-01]],
#
#          [[ 2.3921e-01]],
#
#          [[ 1.2690e-02]],
#
#          [[ 1.9108e+00]],
#
#          [[ 1.8664e-01]],
#
#          [[-2.1714e-01]],
#
#          [[ 2.7151e-01]],
#
#          [[-2.3559e-01]],
#
#          [[-2.7134e-02]],
#
#          [[ 1.8870e-01]],
#
#          [[-1.9975e-01]],
#
#          [[-5.5561e-01]],
#
#          [[-1.9137e-01]],
#
#          [[ 1.4883e-03]],
#
#          [[ 1.9612e-01]],
#
#          [[-8.4047e-01]],
#
#          [[ 8.2748e-01]],
#
#          [[-2.8923e-01]],
#
#          [[ 7.7582e-01]],
#
#          [[ 7.2615e-01]],
#
#          [[ 3.2726e-01]],
#
#          [[-3.8343e-01]],
#
#          [[ 1.8274e-01]],
#
#          [[ 4.5975e-01]],
#
#          [[ 2.0209e-01]],
#
#          [[-1.9635e-01]],
#
#          [[-1.6976e-01]],
#
#          [[-3.1694e-02]],
#
#          [[ 4.9447e-03]]]], requires_grad=True)
# gammas.16 Parameter containing:
# tensor([[[[ 0.2088]],
#
#          [[-0.2195]],
#
#          [[ 0.3969]],
#
#          [[ 0.2789]],
#
#          [[ 0.3635]],
#
#          [[-0.1954]],
#
#          [[ 0.1788]],
#
#          [[ 0.1970]],
#
#          [[-0.2164]],
#
#          [[ 0.2196]],
#
#          [[-0.3798]],
#
#          [[-0.3181]],
#
#          [[ 0.0284]],
#
#          [[-0.4726]],
#
#          [[-0.2977]],
#
#          [[-0.2058]],
#
#          [[-0.5055]],
#
#          [[ 0.1491]],
#
#          [[-0.9746]],
#
#          [[ 0.3487]],
#
#          [[-0.1955]],
#
#          [[-0.1727]],
#
#          [[ 0.7563]],
#
#          [[ 0.2405]],
#
#          [[ 0.1877]],
#
#          [[-0.3085]],
#
#          [[-0.2353]],
#
#          [[-0.1787]],
#
#          [[-0.3994]],
#
#          [[-0.2070]],
#
#          [[ 0.2982]],
#
#          [[ 0.2332]],
#
#          [[ 0.2528]],
#
#          [[-0.2731]],
#
#          [[-0.2351]],
#
#          [[ 0.1762]],
#
#          [[-0.2738]],
#
#          [[ 0.3484]],
#
#          [[ 0.0049]],
#
#          [[-0.2265]],
#
#          [[-0.4134]],
#
#          [[-0.3223]],
#
#          [[ 0.2944]],
#
#          [[ 0.1941]],
#
#          [[-0.2076]],
#
#          [[ 0.3431]],
#
#          [[ 0.6270]],
#
#          [[-0.1541]],
#
#          [[ 0.2861]],
#
#          [[-0.3533]],
#
#          [[-0.1925]],
#
#          [[ 0.3444]],
#
#          [[ 1.7990]],
#
#          [[ 0.3590]],
#
#          [[ 0.5157]],
#
#          [[ 0.0028]],
#
#          [[-0.2090]],
#
#          [[ 0.0314]],
#
#          [[ 0.4600]],
#
#          [[ 0.4229]],
#
#          [[ 0.1719]],
#
#          [[-1.3903]],
#
#          [[ 0.3365]],
#
#          [[-0.2133]]]], requires_grad=True)
# gammas.17 Parameter containing:
# tensor([[[[-0.3165]],
#
#          [[-0.0098]],
#
#          [[-0.0464]],
#
#          [[ 0.1578]],
#
#          [[ 0.0098]],
#
#          [[ 0.0584]],
#
#          [[ 0.0063]],
#
#          [[-0.0583]],
#
#          [[-0.0772]],
#
#          [[ 0.0333]],
#
#          [[-0.0479]],
#
#          [[-0.0321]],
#
#          [[ 0.0406]],
#
#          [[ 0.0830]],
#
#          [[ 0.0204]],
#
#          [[ 0.0135]],
#
#          [[ 0.0207]],
#
#          [[ 0.1049]],
#
#          [[-0.0430]],
#
#          [[ 0.0809]],
#
#          [[-0.2189]],
#
#          [[ 0.0178]],
#
#          [[ 0.0507]],
#
#          [[-0.0521]],
#
#          [[-0.0155]],
#
#          [[-0.0393]],
#
#          [[ 0.0374]],
#
#          [[-0.0413]],
#
#          [[ 0.0367]],
#
#          [[-0.1381]],
#
#          [[ 0.0138]],
#
#          [[ 0.0005]],
#
#          [[ 0.0151]],
#
#          [[-0.0370]],
#
#          [[ 0.0185]],
#
#          [[-0.0120]],
#
#          [[-0.0433]],
#
#          [[ 0.0270]],
#
#          [[-0.0255]],
#
#          [[-0.0764]],
#
#          [[-0.0175]],
#
#          [[ 0.0590]],
#
#          [[ 0.0423]],
#
#          [[ 0.0477]],
#
#          [[ 0.0135]],
#
#          [[ 0.0154]],
#
#          [[ 0.2075]],
#
#          [[-0.0322]],
#
#          [[-0.0286]],
#
#          [[ 0.0197]],
#
#          [[-0.0317]],
#
#          [[ 0.0505]],
#
#          [[ 0.2091]],
#
#          [[-0.1186]],
#
#          [[ 0.0106]],
#
#          [[-0.0277]],
#
#          [[ 0.0159]],
#
#          [[ 0.0417]],
#
#          [[ 0.0308]],
#
#          [[-0.0233]],
#
#          [[-0.0138]],
#
#          [[ 0.0826]],
#
#          [[ 0.1214]],
#
#          [[ 0.1964]]]], requires_grad=True)

# %%
# choose the size of the sample patch: 
patch_size = (C,40,40) #choose 28x28 for mnist patch size
x_c = torch.zeros(patch_size) 
if torch.cuda.is_available():
    x = x.cuda()

synth = synthesis() 
sample, interm_Ys = univ_inv_sol(denoiser, 
                                 x_c = x_c, 
                                 task = synth,
                                 sig_0 = 1,
                                 sig_L = 0.01, 
                                 h0 = 0.01, 
                                 beta = 0.5,  # change beta to see how quality of generated samples change       
                                 freq = 5)

## plot the progression and the final sample
plot_synthesis(interm_Ys, sample)
# Out:
# ----------------------------- 5
# sigma  0.9166770577430725
# ----------------------------- 10
# sigma  0.7716110944747925
# ----------------------------- 15
# sigma  0.5906547904014587
# ----------------------------- 20
# sigma  0.39790722727775574
# ----------------------------- 25
# sigma  0.2446519285440445
# ----------------------------- 30
# sigma  0.1391778588294983
# ----------------------------- 35
# sigma  0.06978001445531845
# ----------------------------- 40
# sigma  0.0336601659655571
# ----------------------------- 45
# sigma  0.01422815304249525
# -------- total number of iterations,  48
# -------- average time per iteration (s),  0.0153
# value range 0.35 0.55

# %%
betas = [1,0.1,0.01,0.001]
for beta in betas:
    sample, interm_Ys = univ_inv_sol_plot(denoiser, 
                                 x_c = x_c, 
                                 task = synth,
                                 sig_0 = 1,
                                 sig_L = 0.01, 
                                 h0 = 0.01, 
                                 beta = beta,  # change beta to see how quality of generated samples change       
                                 freq = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22760\1158731787.py in <module>
#       1 betas = [1,0.1,0.01,0.001]
#       2 for beta in betas:
# ----> 3     sample, interm_Ys = univ_inv_sol_plot(denoiser,
#       4                                  x_c = x_c,
#       5                                  task = synth,
#
# NameError: name 'univ_inv_sol_plot' is not defined

# %%
def compute_circle_points(radius, num_points):
    angles = np.linspace(0, 2 * np.pi, num_points, endpoint=False)
    x = radius * np.cos(angles)
    y = radius * np.sin(angles)
    points = np.column_stack((x, y))
    return points

# %%
# Example: Compute 10 points on a circle with radius 5
radius = 1
num_points = 100
circle_points = compute_circle_points(radius, num_points)

plt.plot(circle_points[:,0],circle_points[:,1])

# %%
class GaussDistribution():
    """
    Gaussian distribution with mean (mu) and standard deviation (sigma).

    Parameters:
    - loc (Any): Mean of the distribution. Default is 0.
    - scale (Any): Standard deviation of the distribution. Default is 1.

    Methods:
    - rsample(sample_shape): Generates random samples from the distribution.
    - log_prob(value): Computes the log probability of a given value under the distribution.
    """

    def __init__(self, loc = 0., scale = 1.) -> None:
        """
        Initializes the Gaussian distribution with given mean and standard deviation.

        Args:
        - loc (Any): Mean of the distribution. Default is 0.
        - scale (Any): Standard deviation of the distribution. Default is 1.
        """
        super().__init__()
        
        if not torch.is_tensor(loc):
            self.mu = torch.tensor(loc, dtype=torch.float32)
        else:
            self.mu = loc

        if not torch.is_tensor(scale):
            self.sigma = torch.tensor(scale, dtype=torch.float32)
        else:
            self.sigma = scale

    def sample(self, sample_shape:torch.Size = torch.Size()):
        """
        Generates random samples from the Gaussian distribution.

        Args:
        - sample_shape: Shape of the random samples to be generated.

        Returns:
        - samples: Random samples from the distribution.
        """
        if not isinstance(sample_shape, torch.Size):
            sample_shape = torch.Size(sample_shape)
        
        shape = sample_shape + self.mu.size()
        with torch.no_grad():
            eps = torch.randn(shape, dtype=self.mu.dtype)
            return self.mu + eps * self.sigma
    
    def rsample(self, sample_shape:torch.Size = torch.Size()):
        """
        Generates random samples from the Gaussian distribution.

        Args:
        - sample_shape: Shape of the random samples to be generated.

        Returns:
        - samples: Random samples from the distribution.
        """
        if not isinstance(sample_shape, torch.Size):
            sample_shape = torch.Size(sample_shape)
        
        shape = sample_shape + self.mu.size()

        eps = torch.randn(shape, dtype=self.mu.dtype)
        
        return self.mu + eps * self.sigma
    

    def log_prob(self, value):
        """
        Computes the log probability of a given value under the Gaussian distribution.

        Args:
        - value: Tensor of values for which log probabilities are computed.

        Returns:
        - log_p: Log probabilities of the given values.
        """
        eps = torch.finfo(torch.float32).eps

        log_p = - 0.5 * torch.log(2 * torch.tensor(np.pi, dtype=torch.float32)) \
                - 0.5 * torch.log(self.sigma**2 + eps) \
                - 0.5 * torch.square(value - self.mu) / (self.sigma**2 + eps)

        return log_p

    # def prob(self, value):
    #     """
    #     Computes the log probability of a given value under the Gaussian distribution.

    #     Args:
    #     - value: Tensor of values for which log probabilities are computed.

    #     Returns:
    #     - log_p: Log probabilities of the given values.
    #     """
    #     eps = torch.finfo(torch.float32).eps

    #     p = torch.exp(-0.5* torch.square(value - self.mu)/ (self.sigma**2 + eps)) / 

    #     return p

# %%
def multivariate_gaussian_pdf(mean, covariance):
    k = len(mean)
    det_covariance = np.linalg.det(covariance)
    inv_covariance = np.linalg.inv(covariance)
    def pdf(y):
        y = np.array(y)
        exponent = -0.5 * np.dot(np.dot((y - mean).T, inv_covariance), (y - mean))
        coefficient = 1 / np.sqrt((2 * np.pi) ** k * det_covariance)
    
        return  coefficient * np.exp(exponent)
    
    return pdf

# %%
gaussian_pdf = multivariate_gaussian_pdf(np.array([0,0]),np.diag([1,1]))

# %%
gauss_dist = GaussDistribution(scale=0.5)

# %%
p_x = 1. / num_points
log_p_x = torch.log( torch.FloatTensor([1. / num_points] ))

x = torch.FloatTensor(circle_points)

# %%
ys = list()
y = torch.rand(size=(2,))
y
# Out:
# tensor([0.1628, 0.4921])

# %%
y / torch.norm(y)
# Out:
# tensor([0.3141, 0.9494])

# %%
log_p_y_given_x = gauss_dist.log_prob(x-y).sum(dim=-1) # (num_points,)

print(log_p_y_given_x.shape)
log_p_y = torch.logsumexp(log_p_y_given_x  + log_p_x, dim=0) #integrale sur x  # (1,) 

print(log_p_y.shape)
log_p_x_given_y = log_p_y_given_x + log_p_x - log_p_y # (num_points,)
    
print(log_p_x_given_y.shape)
p_x_given_y = torch.exp(log_p_x_given_y) # (num_points,)
print(p_x_given_y.shape)
x_hat = (x * p_x_given_y[:,None]).sum(dim = 0) #(2,)
print(x_hat.shape)
x_hat
# Out:
# torch.Size([100])
# torch.Size([])
# torch.Size([100])
# torch.Size([100])
# torch.Size([2])
# tensor([0.2229, 0.6735])

# %%
ys.append(np.array(y))
y = x_hat

# %%
ys_array = np.array(ys)
y_xs = ys_array[:,0]
y_ys = ys_array[:,1]
plt.plot(circle_points[:,0],circle_points[:,1])
plt.plot(y_xs,y_ys,color = 'red',marker="x")

# %%
def circle_demo(h0=0.05, beta = 1., sigma_L = 1e-2):
    radius = 1
    num_points = 100
    circle_points = compute_circle_points(radius, num_points)

    N = 2
    p_x = 1. / num_points
    log_p_x = torch.log( torch.FloatTensor([1. / num_points] ))

    x = torch.FloatTensor(circle_points)

    #Initialize y
    
    y = torch.rand(size=(2,))
    y_numpy = y.numpy()
    ys = [y_numpy]

    gauss_dist = GaussDistribution(scale=0.1)

    sigma = 1

    t = 1
    while t < 100:
        gauss_dist = GaussDistribution(scale=sigma)
        # compute x_hat

        log_p_y_given_x = gauss_dist.log_prob(x-y).sum(dim=-1) # (num_points,)

        log_p_y = torch.logsumexp(log_p_y_given_x  + log_p_x, dim=0) #integrale sur x  # (1,) 

        log_p_x_given_y = log_p_y_given_x + log_p_x - log_p_y # (num_points,)
            

        p_x_given_y = torch.exp(log_p_x_given_y) # (num_points,)

        x_hat = (x * p_x_given_y[:,None]).sum(dim = 0) #(2,)



        h = h0*t/(1+ (h0*(t-1)) )

        d = x_hat - y # - M(M_T(f_y[0])) + ( M(M_T(y[0]))  - M(x_c) )


        sigma = torch.norm(d)/np.sqrt(N)

        gamma = sigma*np.sqrt(((1 - (beta*h))**2 - (1-h)**2 ))

        noise = torch.randn(N,)

        print(gamma*noise)
        if torch.cuda.is_available():
            noise = noise.cuda()

        y = y -  h*d + gamma*noise
        y = x_hat
        y_numpy = y.numpy()
        t +=1
        if np.linalg.norm(sigma) < sigma_L:
            break
        ys.append(y_numpy)
        print(y_numpy)

    print(ys)
    print(y_numpy)
    ys_array = np.array(ys)
    y_xs = ys_array[:,0]
    y_ys = ys_array[:,1]
    print(ys_array)
    plt.plot(circle_points[:,0],circle_points[:,1])
    plt.plot(y_xs,y_ys,color = 'red',marker="o")

    for i,(y_x,y_y) in enumerate(zip(y_xs,y_ys)):
        plt.text(y_x,y_y,str(i) )

# %%
circle_demo(beta=1)
# Out:
# tensor([-0., -0.])
# [0.11822826 0.00832446]
# tensor([-0., -0.])
# [0.96663326 0.06806061]
# tensor([0., -0.])
# [0.78123    0.05500637]
# tensor([-0., 0.])
# [0.98646826 0.0694572 ]
# tensor([0., 0.])
# [array([0.238137  , 0.01676726], dtype=float32), array([0.11822826, 0.00832446], dtype=float32), array([0.96663326, 0.06806061], dtype=float32), array([0.78123   , 0.05500637], dtype=float32), array([0.98646826, 0.0694572 ], dtype=float32)]
# [0.98679686 0.06948034]
# [[0.238137   0.01676726]
#  [0.11822826 0.00832446]
#  [0.96663326 0.06806061]
#  [0.78123    0.05500637]
#  [0.98646826 0.0694572 ]]

# %% [markdown]
# # Inverse problems
#
#
# Here, we use the implicit prior of the denoiser to solve linear inverse problems (i.e., recovery of an image from a partial set of linear measurements).  The same function is used to solve all problems.  In addition to the hyperparameters used in the sampling algorithm above, the linear inverse algorithm requires specification of the measurement matrix (i.e. the forward model). We provide 5 different classes: inpainting, random pixel dropping, super resolution, deblurring, and measurements on random basis (i.e. compressive sensing). You can use the algorithm for any other linear inverse problems, as long as you provide it with the forward model.

# %% [markdown]
# ## Load a test image

# %%
# Choose a test dataset
# Note: grayscale/color of the test images must be consistent with grayscale/color of denoiser training data
if grayscale is True: 
    path = 'test_images/grayscale/'
else: 
    path = 'test_images/color/'
print('Test datasets: ', os.listdir(path))

test_folder = 'Set14'
# Out:
# Test datasets:  ['BSD100', 'Set14', 'Set5']

# %%
# choose an image number
im_num = 6

X = test_image(grayscale, path+test_folder+'/', im_num)
X.show()

# %%
# crop a portion of the image (smaller will run faster)
x = X.crop(210,250,60,60)
x.shape
# Out:
# torch.Size([3, 60, 60])

# %%
x.shape
# Out:
# torch.Size([3, 60, 60])

# %% [markdown]
# ## 1. Inpainting

# %%
# Specify top-left corner and size of "hole" to be inpainted (filled in) ***
inpaint = inpainting(x_size=x.size(), y0=25, x0=35, h=20, w=20)

plot_corrupted_im(inpaint.M(inpaint.M_T(x)))

# %%
# In solving linear inverse problems, in order to get good quality samples, beta should be small, that is lots of 
# added noise in each iteration. 
# This gives the algorithm the freedom to explore the space and arrive at a point on the manifold where the 
# linear constraint is satisfied

sample, interm_Ys = univ_inv_sol(denoiser, 
                                 x_c = inpaint.M_T(x), 
                                 task = inpaint,
                                 sig_0 = 1,
                                 sig_L = 0.01, 
                                 h0 = 0.01, 
                                 beta = 0.01,          
                                 freq = 40)
plot_all_samples(sample, interm_Ys)
# Out:
# ----------------------------- 40
# sigma  0.5274801850318909
# ----------------------------- 80
# sigma  0.1388469636440277
# ----------------------------- 120
# sigma  0.024865897372364998
# -------- total number of iterations,  142
# -------- average time per iteration (s),  0.0031

# %%
plot_sample(x, inpaint.M(inpaint.M_T(x)), sample)

# %% [markdown]
# ## 2. Missing random pixels

# %%
# Retain a random subset of pixels. 
rand_pix = rand_pixels(x_size = x.size(), p = 0.2) # p = fraction of pixels kept

print_dim(measurment_dim=rand_pix.mask.sum().item(), image_dim=np.prod(x.shape))

sample, interm_Ys = univ_inv_sol(denoiser, 
                                 x_c = rand_pix.M_T(x), 
                                 task = rand_pix,
                                 sig_0 = 1 ,
                                 sig_L = 0.01, 
                                 h0 = 0.01, 
                                 beta = 0.01,          
                                 freq = 40)

plot_sample(x, rand_pix.M(rand_pix.M_T(x)), sample)
# Out:
# *** Retained 2160 / 10800 (20.0%) of dimensions
# ----------------------------- 40
# sigma  0.016744641587138176
# -------- total number of iterations,  52
# -------- average time per iteration (s),  0.002

# %% [markdown]
# ## 3. Super resolution

# %%
# Subsample image by factor of s (both horizontally and vertially)
super_res = super_resolution(x_size=x.size(), s = 4)

print_dim(measurment_dim=np.prod(super_res.M_T(x).shape), image_dim=np.prod(x.shape))

sample , interm_Ys = univ_inv_sol(denoiser, 
                                  x_c = super_res.M_T(x), 
                                  task = super_res,
                                  sig_0 = 1 ,
                                  sig_L = 0.01, 
                                  h0 = 0.01, 
                                  beta = 0.01,          
                                  freq = 40)

plot_sample(x,super_res.M(super_res.M_T(x)), sample)
# Out:
# *** Retained 675 / 10800 (6.25%) of dimensions
# ----------------------------- 40
# sigma  0.02247464843094349
# -------- total number of iterations,  75
# -------- average time per iteration (s),  0.0027

# %% [markdown]
# ## 4. Random basis

# %%
# Project image onto a random set of basis functions
rand_basis = random_basis(x_size = x.shape , p = 0.2) # p = fraction of dimensions kept

print_dim(measurment_dim=rand_basis.U.shape[1], image_dim=np.prod(x.shape))

sample, interm_Ys = univ_inv_sol(denoiser, 
                                 x_c = rand_basis.M_T(x), 
                                 task = rand_basis,
                                 sig_0 = 1,
                                 sig_L = 0.01, 
                                 h0 = 0.01, 
                                 beta = .01,          
                                 freq = 40)

plot_sample(x, rand_basis.M(rand_basis.M_T(x)), sample)
# Out:
# code\Utils_inverse_prob.py:386: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# The boolean parameter 'some' has been replaced with a string parameter 'mode'.
# Q, R = torch.qr(A, some)
# should be replaced with
# Q, R = torch.linalg.qr(A, 'reduced' if some else 'complete') (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\BatchLinearAlgebra.cpp:2355.)
#   self.U, _ = torch.qr(torch.randn(int(np.prod(x_size)),int(np.prod(x_size)*p) ))
# *** Retained 2160 / 10800 (20.0%) of dimensions
# ----------------------------- 40
# sigma  0.01790669932961464
# -------- total number of iterations,  52
# -------- average time per iteration (s),  0.021

# %% [markdown]
# ## 5. Spectral super resolution

# %%
# Project onto low frequencies (a subset of the Fourier basis)
spec_super_res = spectral_super_resolution(x_size= x.size(), p = 0.2) # p=fraction of low frequencies kept

print_dim(measurment_dim=spec_super_res.mask.sum()*C, image_dim=np.prod(x.shape))

sample , interm_Ys = univ_inv_sol(denoiser, 
                                  x_c=spec_super_res.M_T(x), 
                                  task = spec_super_res,
                                  sig_0=1 ,
                                  sig_L=.01, 
                                  h0=.01, 
                                  beta = 0.01,          
                                  freq = 40)

plot_sample(x, spec_super_res.M(spec_super_res.M_T(x) ), sample)
# Out:
# *** Retained 2028 / 10800 (18.778%) of dimensions
# ----------------------------- 40
# sigma  0.017372865229845047
# -------- total number of iterations,  59
# -------- average time per iteration (s),  0.0031
